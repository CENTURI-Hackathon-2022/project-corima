# %%
from skimage import io
import os
import matplotlib.pyplot as plt

from PIL import Image
from PIL.TiffTags import TAGS

# %%
img_path = os.getcwd() + '/monocytes/'

filename_opt ='topo_20220107_Exp2Cell8map-data-2022.01.07-16.34.34.510_processed-2022.01.10-12.38.51.tif'
filename_mec ='20220117_E2_Cell8BF.tif'

io.use_plugin('pil')
img_opt = io.imread(img_path + filename_opt)
img_mec = io.imread(img_path + filename_mec)

img_optb=Image.open(img_path + filename_opt)
    
meta_dict = {TAGS[key] : img_optb.tag[key] for key in img_optb.tag_v2}

meta_dict
#print(img_optb)
# Out:
# {'ImageWidth': (64,),
#  'ImageLength': (64,),
#  'BitsPerSample': (32,),
#  'Compression': (1,),
#  'PhotometricInterpretation': (1,),
#  'ImageDescription': ('no info',),
#  'StripOffsets': (8,),
#  'SampleFormat': (3,),
#  'SamplesPerPixel': (1,),
#  'RowsPerStrip': (64,),
#  'StripByteCounts': (16384,),
#  'XResolution': ((4294967295, 201326),),
#  'YResolution': ((4294967295, 201326),),
#  'PlanarConfiguration': (1,),
#  'ResolutionUnit': (3,),
#  'Software': ('asd2tiff_GUI - Arin Marchesi modified by FR',),
#  'DateTime': ('1 ms x frame       ',)}

# %%
plt.imshow(img_opt)

# %%
plt.imshow(img_mec)

# %%
plt.imshow(img_mec)
